# %%
# Suppressing Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Suppressing Warnings
import pandas as pd
import seaborn as sns
import numpy as np
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %%
# Importing all datasets
churn_data = pd.read_csv("churn_data.csv")
churn_data
# Out:
#       customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0     7590-VHVEG       1           No  Month-to-month              Yes
# 1     5575-GNVDE      34          Yes        One year               No
# 2     3668-QPYBK       2          Yes  Month-to-month              Yes
# 3     7795-CFOCW      45           No        One year               No
# 4     9237-HQITU       2          Yes  Month-to-month              Yes
# 5     9305-CDSKC       8          Yes  Month-to-month              Yes
# 6     1452-KIOVK      22          Yes  Month-to-month              Yes
# 7     6713-OKOMC      10           No  Month-to-month               No
# 8     7892-POOKP      28          Yes  Month-to-month              Yes
# 9     6388-TABGU      62          Yes        One year               No
# 10    9763-GRSKD      13          Yes  Month-to-month              Yes
# 11    7469-LKBCI      16          Yes        Two year               No
# ...

# %%
customer_data = pd.read_csv("customer_data.csv")
customer_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No

# %%
internet_data = pd.read_csv("internet_data.csv")
internet_data.head()
# Out:
#    customerID     MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  7590-VHVEG  No phone service             DSL             No          Yes
# 1  5575-GNVDE                No             DSL            Yes           No
# 2  3668-QPYBK                No             DSL            Yes          Yes
# 3  7795-CFOCW  No phone service             DSL            Yes           No
# 4  9237-HQITU                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies
# 0               No          No          No              No
# 1              Yes          No          No              No
# 2               No          No          No              No
# 3              Yes         Yes          No              No
# 4               No          No          No              No

# %%
# Merging on 'customerID'
df_1 = pd.merge(churn_data, customer_data, how='inner', on='customerID')

# %%
df_1
# Out:
#       customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0     7590-VHVEG       1           No  Month-to-month              Yes
# 1     5575-GNVDE      34          Yes        One year               No
# 2     3668-QPYBK       2          Yes  Month-to-month              Yes
# 3     7795-CFOCW      45           No        One year               No
# 4     9237-HQITU       2          Yes  Month-to-month              Yes
# 5     9305-CDSKC       8          Yes  Month-to-month              Yes
# 6     1452-KIOVK      22          Yes  Month-to-month              Yes
# 7     6713-OKOMC      10           No  Month-to-month               No
# 8     7892-POOKP      28          Yes  Month-to-month              Yes
# 9     6388-TABGU      62          Yes        One year               No
# 10    9763-GRSKD      13          Yes  Month-to-month              Yes
# 11    7469-LKBCI      16          Yes        Two year               No
# ...

# %%
# Final dataframe with all predictor variables
df2= pd.merge(df_1, internet_data, how='inner', on='customerID')
# Let's see the head of our master dataset
df2.head()
# Out:
#    customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0  7590-VHVEG       1           No  Month-to-month              Yes
# 1  5575-GNVDE      34          Yes        One year               No
# 2  3668-QPYBK       2          Yes  Month-to-month              Yes
# 3  7795-CFOCW      45           No        One year               No
# 4  9237-HQITU       2          Yes  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn  gender  \
# 0           Electronic check           29.85        29.85    No  Female
# 1               Mailed check           56.95       1889.5    No    Male
# 2               Mailed check           53.85       108.15   Yes    Male
# 3  Bank transfer (automatic)           42.30      1840.75    No    Male
# 4           Electronic check           70.70       151.65   Yes  Female
#
#         ...        Partner Dependents     MultipleLines InternetService  \
# ...

# %%
# Let's check the dimensions of the dataframe
df2.shape
# Out:
# (7043, 21)

# %%
# let's look at the statistical aspects of the dataframe
df2.describe()
# Out:
#             tenure  MonthlyCharges  SeniorCitizen
# count  7043.000000     7043.000000    7043.000000
# mean     32.371149       64.761692       0.162147
# std      24.559481       30.090047       0.368612
# min       0.000000       18.250000       0.000000
# 25%       9.000000       35.500000       0.000000
# 50%      29.000000       70.350000       0.000000
# 75%      55.000000       89.850000       0.000000
# max      72.000000      118.750000       1.000000

# %%
# Let's see the type of each column
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
# customerID          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7043 non-null object
# Churn               7043 non-null object
# gender              7043 non-null object
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null object
# Dependents          7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# ...

# %%
sns.heatmap(df2.corr(),annot=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df2['PhoneService']=le.fit_transform(df2['PhoneService'])
df2['Contract']=le.fit_transform(df2['Contract'])
df2['PaperlessBilling']=le.fit_transform(df2['PaperlessBilling'])
df2['TotalCharges']=le.fit_transform(df2['TotalCharges'])
df2['Churn']=le.fit_transform(df2['Churn'])
df2['Partner']=le.fit_transform(df2['Partner'])
df2['Dependents']=le.fit_transform(df2['Dependents'])
df2['MultipleLines']=le.fit_transform(df2['MultipleLines'])
df2['InternetService']=le.fit_transform(df2['InternetService'])
df2['OnlineSecurity']=le.fit_transform(df2['OnlineSecurity'])
df2['OnlineBackup']=le.fit_transform(df2['OnlineBackup'])
df2['DeviceProtection']=le.fit_transform(df2['DeviceProtection'])
df2['TechSupport']=le.fit_transform(df2['TechSupport'])
df2['StreamingTV']=le.fit_transform(df2['StreamingTV'])
df2['StreamingMovies']=le.fit_transform(df2['StreamingMovies'])
df2['PaymentMethod']=le.fit_transform(df2['PaymentMethod'])
df2['gender']=le.fit_transform(df2['gender'])

# %%
df2.columns
# Out:
# Index(['customerID', 'tenure', 'PhoneService', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn', 'gender',
#        'SeniorCitizen', 'Partner', 'Dependents', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies'],
#       dtype='object')

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df2.corr(),annot=True)

# %%
sns.barplot('Churn','tenure',data=df2)

# %%
sns.barplot('Churn','Contract',data=df2)

# %%
sns.barplot('Churn','OnlineSecurity',data=df2)

# %%
sns.barplot('Churn','TechSupport',data=df2)

# %%
y=df2['Churn']
X=df2[['tenure', 'PhoneService', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'gender',
       'SeniorCitizen', 'Partner', 'Dependents', 'MultipleLines',
       'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
       'TechSupport', 'StreamingTV', 'StreamingMovies']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=1000)
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred=rfc.predict(X_test)

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
print(classification_report(y_test,y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.82      0.91      0.86      1546
#           1       0.64      0.45      0.53       567
#
# avg / total       0.77      0.78      0.77      2113

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.783719829626124

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[1403  143]
#  [ 314  253]]

# %%
result=pd.DataFrame(rfc.feature_importances_*100,index=X_train.columns,columns=['GiniValuePercentage'])
result.sort_values(by='GiniValuePercentage',ascending=False).head()
# Out:
#                 GiniValuePercentage
# tenure                    17.682970
# MonthlyCharges            17.479919
# TotalCharges              16.587391
# Contract                   7.607734
# PaymentMethod              5.478974

# %%
plt.yscale('log')
sns.barplot('Churn','MonthlyCharges',data=df2,estimator=np.mean)

# %%
plt.yscale('log')
sns.barplot('Churn','tenure',data=df2,estimator=np.mean)

# %%
 plt.yscale('log')
sns.barplot('Churn','TotalCharges',data=df2,estimator=np.mean)

# %%
plt.yscale('log')
sns.barplot('Churn','Contract',data=df2,estimator=np.mean)

# %%
plt.yscale('log')
sns.barplot('Churn','PaymentMethod',data=df2,estimator=np.mean)

# %%
sns.countplot(df_1['PaymentMethod'])

# %%
df11=df_1[df_1['Churn']=='Yes']
df12=pd.DataFrame(df11.groupby(['PaymentMethod'])['Churn'].count()).plot(kind='bar')
# One of the disadvantages of electronic payment system is that you need to protect financial information stored in your business's computer systems from unauthorized access of other people working in your organization.
df17=df11.groupby(['PaymentMethod'])['Churn'].count()
df12

# %%
df13=pd.DataFrame(df_1[df_1['PaymentMethod']=='Electronic check']['Churn'])
round(df13[df13['Churn']=='Yes'].count()/len(df13)*100,2)
# Out:
# Churn    45.29
# dtype: float64

# %%
df_1['TotalCharges']=pd.to_numeric(df_1['TotalCharges'],errors='correc')
df_1['Charges_diff']=df_1['TotalCharges']-df_1['MonthlyCharges']
df_1['Charges_diff'].fillna(value=df_1['Charges_diff'].mean(),inplace=True)
print(round(df_1[df_1['Churn']=='Yes'].count()/len(df_1)*100,2))
df14=df_1[df_1['Churn']=='Yes']
# Out:
# customerID          26.54
# tenure              26.54
# PhoneService        26.54
# Contract            26.54
# PaperlessBilling    26.54
# PaymentMethod       26.54
# MonthlyCharges      26.54
# TotalCharges        26.54
# Churn               26.54
# gender              26.54
# SeniorCitizen       26.54
# Partner             26.54
# Dependents          26.54
# Charges_diff        26.54
# dtype: float64

# %%
df15=df14[df14['Contract']=='Month-to-month']

round(df15[df15['Charges_diff']>0].count()*100/len(df15),2)
# Out:
# customerID          77.04
# tenure              77.04
# PhoneService        77.04
# Contract            77.04
# PaperlessBilling    77.04
# PaymentMethod       77.04
# MonthlyCharges      77.04
# TotalCharges        77.04
# Churn               77.04
# gender              77.04
# SeniorCitizen       77.04
# Partner             77.04
# Dependents          77.04
# Charges_diff        77.04
# dtype: float64

# %%
df16=df_1[df_1['Contract']=='One year']
round(df16[df16['Churn']=='Yes'].count()*100/len(df16),2)
# Out:
# customerID          11.27
# tenure              11.27
# PhoneService        11.27
# Contract            11.27
# PaperlessBilling    11.27
# PaymentMethod       11.27
# MonthlyCharges      11.27
# TotalCharges        11.27
# Churn               11.27
# gender              11.27
# SeniorCitizen       11.27
# Partner             11.27
# Dependents          11.27
# Charges_diff        11.27
# dtype: float64

# %%
df14
# Out:
#       customerID  tenure PhoneService        Contract PaperlessBilling  \
# 2     3668-QPYBK       2          Yes  Month-to-month              Yes
# 4     9237-HQITU       2          Yes  Month-to-month              Yes
# 5     9305-CDSKC       8          Yes  Month-to-month              Yes
# 8     7892-POOKP      28          Yes  Month-to-month              Yes
# 13    0280-XJGEX      49          Yes  Month-to-month              Yes
# 18    4190-MFLUW      10          Yes  Month-to-month               No
# 20    8779-QRDMV       1           No  Month-to-month              Yes
# 22    1066-JKSGK       1          Yes  Month-to-month               No
# 26    6467-CHFZW      47          Yes  Month-to-month              Yes
# 27    8665-UTDHZ       1           No  Month-to-month               No
# 29    8773-HHUOZ      17          Yes  Month-to-month              Yes
# 36    6047-YHPVI       5          Yes  Month-to-month              Yes
# ...

# %%
df16
# Out:
#       customerID  tenure PhoneService  Contract PaperlessBilling  \
# 1     5575-GNVDE      34          Yes  One year               No
# 3     7795-CFOCW      45           No  One year               No
# 9     6388-TABGU      62          Yes  One year               No
# 12    8091-TTVAX      58          Yes  One year               No
# 16    8191-XWSZG      52          Yes  One year               No
# 21    1680-VDCWW      12          Yes  One year               No
# 32    6827-IEAUQ      27          Yes  One year               No
# 40    8865-TNMNX      10          Yes  One year               No
# 42    9867-JCZSP      17          Yes  One year               No
# 54    4667-QONEA      60          Yes  One year              Yes
# 56    8769-KKTPH      63          Yes  One year              Yes
# 57    5067-XJQFU      66          Yes  One year              Yes
# 63    0557-ASKVU      18          Yes  One year              Yes
# ...

# %%
df16['New_total_diff_yearly']=df_1['TotalCharges']-(df_1['MonthlyCharges']*12)

# %%
df16
# Out:
#       customerID  tenure PhoneService  Contract PaperlessBilling  \
# 1     5575-GNVDE      34          Yes  One year               No
# 3     7795-CFOCW      45           No  One year               No
# 9     6388-TABGU      62          Yes  One year               No
# 12    8091-TTVAX      58          Yes  One year               No
# 16    8191-XWSZG      52          Yes  One year               No
# 21    1680-VDCWW      12          Yes  One year               No
# 32    6827-IEAUQ      27          Yes  One year               No
# 40    8865-TNMNX      10          Yes  One year               No
# 42    9867-JCZSP      17          Yes  One year               No
# 54    4667-QONEA      60          Yes  One year              Yes
# 56    8769-KKTPH      63          Yes  One year              Yes
# 57    5067-XJQFU      66          Yes  One year              Yes
# 63    0557-ASKVU      18          Yes  One year              Yes
# ...

# %%
round(df16[df16['New_total_diff_yearly']>0].count()*100/len(df16),2)
# Out:
# customerID               92.19
# tenure                   92.19
# PhoneService             92.19
# Contract                 92.19
# PaperlessBilling         92.19
# PaymentMethod            92.19
# MonthlyCharges           92.19
# TotalCharges             92.19
# Churn                    92.19
# gender                   92.19
# SeniorCitizen            92.19
# Partner                  92.19
# Dependents               92.19
# Charges_diff             92.19
# New_total_diff_yearly    92.19
# dtype: float64
