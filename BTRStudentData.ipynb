# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('BTR-QSP-Student-Data.csv')
df.head()
# Out:
#                   Name Gender Date of Birth      Mob No  \
# 0     Shree harsha V K    NaN           NaN  9742872822
# 1          Hemanth N V    NaN           NaN  9886988075
# 2   M S Ramasubramanya   male    11-05-1993  7022021422
# 3  Satya prakash sahoo   male    26-06-1991  9090396977
# 4   Nikhil Chaturvedi     NaN           NaN  9098387116
#
#                       Email Id Fresher/Experience 10th Board  \
# 0   shreeharsha.3042@gmail.com                NaN        NaN
# 1  hemanth_babu_star@yahoo.com                NaN        NaN
# 2  ramasubramanya123@gmail.com            Fresher       SSLC
# 3     spsahoopro1990@gmail.com            Fresher       SSLC
# 4       nikhilchat99@gmail.com                NaN        NaN
#
#    10th Year of Pass out 10th Aggregate 12th Board     ...      \
# 0                    NaN            NaN        NaN     ...
# 1                    NaN            NaN        NaN     ...
# 2                 2009.0         50.00%    Diploma     ...
# ...

# %%
df.to_excel('QSP-Student.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8105 entries, 0 to 8104
# Data columns (total 96 columns):
# Name                                                        8105 non-null object
# Gender                                                      4122 non-null object
# Date of Birth                                               4131 non-null object
# Mob No                                                      8100 non-null object
# Email Id                                                    8100 non-null object
# Fresher/Experience                                          5817 non-null object
# 10th Board                                                  3802 non-null object
# 10th Year of Pass out                                       3777 non-null float64
# 10th Aggregate                                              3770 non-null object
# 12th Board                                                  3771 non-null object
# ...

# %%
round(df.isnull().sum()/len(df)*100,2)
# Out:
# Name                                     0.00
# Gender                                  49.14
# Date of Birth                           49.03
# Mob No                                   0.06
# Email Id                                 0.06
# Fresher/Experience                      28.23
# 10th Board                              53.09
# 10th Year of Pass out                   53.40
# 10th Aggregate                          53.49
# 12th Board                              53.47
# 12th Course Type                        56.93
# 12th/Diploma/ITI Year of Pass out       53.51
# 12th/Diploma/ITI-Aggregate              53.55
# Diploma Course Type                     94.94
# Diploma Stream                          94.95
# Other(Diploma Stream)                   99.90
# Diploma University                      96.51
# Other(Diploma University)               96.77
# Diploma College                         94.97
# Other(Diploma College)                  95.45
# ...

# %%
df['Degree College Name'].isnull().sum()
df['College Place'].isnull().sum()
# Out:
# 4175

# %%
df.columns
# Out:
# Index(['Name', 'Gender', 'Date of Birth', 'Mob No', 'Email Id',
#        'Fresher/Experience', '10th Board', '10th Year of Pass out',
#        '10th Aggregate', '12th Board', '12th Course Type',
#        '12th/Diploma/ITI Year of Pass out', '12th/Diploma/ITI-Aggregate',
#        'Diploma Course Type', 'Diploma Stream', 'Other(Diploma Stream)',
#        'Diploma University', 'Other(Diploma University)', 'Diploma College',
#        'Other(Diploma College)', 'Degree Course Type', 'Degree',
#        'Other(Degree)', 'Stream in Degree', 'Other(Degree Stream)',
#        'Degree Year of Pass out', 'Degree Aggregate', 'CGPA',
#        'Degree University', 'Other(Degree University)',
#        'Degree University Registration No', 'Degree College Name',
#        'Other(Degree College)', 'College Place',
#        'Did You Fail and then clear the subject in Degree',
#        'Have any existing backlogs in Degree?',
#        'Have you got year gap in Degree?',
# ...

# %%
df['Status'].fillna('unknoun',inplace=True)
df['Gender'].fillna('unknoun',inplace=True)
df['Fresher/Experience'].fillna('unknoun',inplace=True)
df['10th Aggregate'].fillna(0,inplace=True)
df['12th/Diploma/ITI-Aggregate'].fillna(0,inplace=True)
df['Stream in Degree'].fillna('unknoun',inplace=True)
df['Degree Year of Pass out'].fillna(0,inplace=True)
df['Degree Aggregate'].fillna(0,inplace=True)
df['City'].fillna('unknoun',inplace=True)
df['State'].fillna('unknoun',inplace=True)
df['Course(s)'].fillna('unknoun',inplace=True)
df['Session'].fillna('unknoun',inplace=True)
df['Mode of Enquiry'].fillna('unknoun',inplace=True)
df['Status'].fillna('unknoun',inplace=True)
df['Approved date'].fillna('unknoun',inplace=True)
df['Degree College Name'].fillna('unknown',inplace=True)
df['College Place'].fillna('unknown',inplace=True)

# %%
df1=df[['Name', 'Gender','Fresher/Experience','10th Aggregate','12th/Diploma/ITI-Aggregate','Stream in Degree',
    'Degree Year of Pass out','Degree Aggregate','Degree College Name','College Place','State','Course(s)',
   'Session', 'Mode of Enquiry','Status','Approved date']]

# %%
df1.head()
# Out:
#                   Name   Gender Fresher/Experience 10th Aggregate  \
# 0     Shree harsha V K  unknoun            unknoun              0
# 1          Hemanth N V  unknoun            unknoun              0
# 2   M S Ramasubramanya     male            Fresher         50.00%
# 3  Satya prakash sahoo     male            Fresher         72.00%
# 4   Nikhil Chaturvedi   unknoun            unknoun              0
#
#   12th/Diploma/ITI-Aggregate      Stream in Degree  Degree Year of Pass out  \
# 0                          0               unknoun                      0.0
# 1                          0               unknoun                      0.0
# 2                     76.77%                 Civil                   2017.0
# 3                     46.00%  Computer Science(CS)                   2011.0
# 4                          0               unknoun                      0.0
#
#   Degree Aggregate                Degree College Name College Place  \
# ...

# %%
df1.shape
# Out:
# (8105, 16)

# %%
df1.isnull().sum()
# Out:
# Name                          0
# Gender                        0
# Fresher/Experience            0
# 10th Aggregate                0
# 12th/Diploma/ITI-Aggregate    0
# Stream in Degree              0
# Degree Year of Pass out       0
# Degree Aggregate              0
# Degree College Name           0
# College Place                 0
# State                         0
# Course(s)                     0
# Session                       0
# Mode of Enquiry               0
# Status                        0
# Approved date                 0
# dtype: int64

# %%
df1.to_excel('BTR-QSP-Students.xlsx')
